# %%
import json
import numpy as np
import random
import tensorflow as tf
import nltk
from nltk.stem import WordNetLemmatizer
import pickle
# !pip install EasyProcess
from keras.models import load_model
# !pip install pyvirtualdisplay
from pyvirtualdisplay import Display



nltk.download('punkt')
nltk.download('wordnet')
lemmatizer=WordNetLemmatizer()
intents=json.loads(open("intents1.json").read())
# Out:
# WARNING:tensorflow:From C:\Users\maheep seharawat\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Requirement already satisfied: EasyProcess in c:\users\maheep seharawat\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: pyvirtualdisplay in c:\users\maheep seharawat\anaconda3\lib\site-packages (3.0)
# [nltk_data] Downloading package punkt to C:\Users\maheep
# [nltk_data]     seharawat\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\maheep
# [nltk_data]     seharawat\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
words=[]
classes=[]
documents=[]
ignoreLetters=['?','!','.',',','@']

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        wordList = nltk.word_tokenize(pattern)
        words.extend(wordList)
        documents.append((wordList, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
words = [lemmatizer.lemmatize(word) for word in words if word not in ignoreLetters]
words = sorted(set(words))

classes = sorted(set(classes))

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

training = []
outputEmpty = [0] * len(classes)

for document in documents:
    bag = []
    wordPatterns = document[0]
    wordPatterns = [lemmatizer.lemmatize(word.lower()) for word in wordPatterns]
    for word in words:
        bag.append(1) if word in wordPatterns else bag.append(0)

    outputRow = list(outputEmpty)
    outputRow[classes.index(document[1])] = 1
    training.append(bag + outputRow)

random.shuffle(training)
training = np.array(training)

trainX = training[:, :len(words)]
trainY = training[:, len(words):]


model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(128, input_shape=(len(trainX[0]),), activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(64, activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(len(trainY[0]), activation='softmax'))

sgd = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(trainX), np.array(trainY), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print('Done')
# Out:
# WARNING:tensorflow:From C:\Users\maheep seharawat\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\maheep seharawat\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\maheep seharawat\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - 2s 9ms/step - loss: 1.3494 - accuracy: 0.2778
# Epoch 2/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.4119 - accuracy: 0.3333
# Epoch 3/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3421 - accuracy: 0.5000
# Epoch 4/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3145 - accuracy: 0.4444
# Epoch 5/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2485 - accuracy: 0.4444
# Epoch 6/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.2321 - accuracy: 0.4444
# Epoch 7/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.2257 - accuracy: 0.5000
# Epoch 8/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1320 - accuracy: 0.5556
# Epoch 9/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1128 - accuracy: 0.5000
# Epoch 10/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9770 - accuracy: 0.7222
# Epoch 11/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1745 - accuracy: 0.5000
# Epoch 12/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9468 - accuracy: 0.7222
# Epoch 13/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9224 - accuracy: 0.7778
# Epoch 14/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9650 - accuracy: 0.5556
# Epoch 15/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9273 - accuracy: 0.6667
# Epoch 16/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8917 - accuracy: 0.6667
# Epoch 17/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8533 - accuracy: 0.6111
# Epoch 18/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8406 - accuracy: 0.6667
# Epoch 19/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8363 - accuracy: 0.7778
# Epoch 20/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8125 - accuracy: 0.8889
# Epoch 21/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7238 - accuracy: 0.8333
# Epoch 22/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8574 - accuracy: 0.7778
# Epoch 23/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7267 - accuracy: 0.8333
# Epoch 24/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5308 - accuracy: 0.8333
# Epoch 25/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7443 - accuracy: 0.7778
# Epoch 26/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6040 - accuracy: 0.8333
# Epoch 27/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7343 - accuracy: 0.8333
# Epoch 28/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6710 - accuracy: 0.8333
# Epoch 29/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5323 - accuracy: 0.8889
# Epoch 30/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5557 - accuracy: 0.7778
# Epoch 31/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6509 - accuracy: 0.8333
# Epoch 32/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4689 - accuracy: 0.8889
# Epoch 33/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5710 - accuracy: 0.7778
# Epoch 34/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5204 - accuracy: 0.8333
# Epoch 35/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5174 - accuracy: 0.8889
# Epoch 36/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4533 - accuracy: 0.8889
# Epoch 37/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4390 - accuracy: 0.8333
# Epoch 38/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5201 - accuracy: 0.7778
# Epoch 39/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3679 - accuracy: 0.8889
# Epoch 40/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4796 - accuracy: 0.7778
# Epoch 41/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4334 - accuracy: 0.8889
# Epoch 42/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3736 - accuracy: 0.8333
# Epoch 43/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4326 - accuracy: 0.8333
# Epoch 44/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4678 - accuracy: 0.7778
# Epoch 45/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1965 - accuracy: 1.0000
# Epoch 46/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3570 - accuracy: 0.8889
# Epoch 47/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2415 - accuracy: 0.9444
# Epoch 48/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3385 - accuracy: 0.8889
# Epoch 49/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2906 - accuracy: 0.8889
# Epoch 50/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3862 - accuracy: 0.8889
# Epoch 51/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3280 - accuracy: 0.8889
# Epoch 52/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4368 - accuracy: 0.8333
# Epoch 53/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2931 - accuracy: 0.8889
# Epoch 54/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2143 - accuracy: 0.8889
# Epoch 55/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3556 - accuracy: 0.8889
# Epoch 56/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2505 - accuracy: 0.9444
# Epoch 57/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2392 - accuracy: 0.9444
# Epoch 58/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2226 - accuracy: 0.9444
# Epoch 59/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1599 - accuracy: 0.9444
# Epoch 60/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2564 - accuracy: 0.9444
# Epoch 61/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4483 - accuracy: 0.8333
# Epoch 62/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2696 - accuracy: 0.9444
# Epoch 63/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3366 - accuracy: 0.8333
# Epoch 64/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2902 - accuracy: 0.8333
# Epoch 65/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2192 - accuracy: 0.9444
# Epoch 66/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2602 - accuracy: 0.8889
# Epoch 67/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3238 - accuracy: 0.9444
# Epoch 68/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3052 - accuracy: 0.9444
# Epoch 69/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2205 - accuracy: 0.9444
# Epoch 70/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1856 - accuracy: 0.9444
# Epoch 71/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2513 - accuracy: 0.9444
# Epoch 72/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3088 - accuracy: 0.8889
# Epoch 73/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1797 - accuracy: 0.8889
# Epoch 74/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2009 - accuracy: 0.9444
# Epoch 75/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2328 - accuracy: 0.9444
# Epoch 76/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2156 - accuracy: 0.9444
# Epoch 77/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2598 - accuracy: 0.8889
# Epoch 78/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2276 - accuracy: 0.8889
# Epoch 79/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3126 - accuracy: 0.9444
# Epoch 80/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1522 - accuracy: 0.8889
# Epoch 81/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1866 - accuracy: 0.8889
# Epoch 82/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2415 - accuracy: 0.8333
# Epoch 83/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2979 - accuracy: 0.8889
# Epoch 84/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2900 - accuracy: 0.8889
# Epoch 85/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3619 - accuracy: 0.9444
# Epoch 86/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1962 - accuracy: 0.9444
# Epoch 87/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2317 - accuracy: 0.9444
# Epoch 88/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1106 - accuracy: 0.9444
# Epoch 89/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1345 - accuracy: 0.9444
# Epoch 90/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1617 - accuracy: 0.9444
# Epoch 91/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2577 - accuracy: 0.9444
# Epoch 92/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1468 - accuracy: 0.9444
# Epoch 93/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2415 - accuracy: 0.9444
# Epoch 94/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2993 - accuracy: 0.8889
# Epoch 95/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2266 - accuracy: 0.9444
# Epoch 96/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3208 - accuracy: 0.8889
# Epoch 97/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2282 - accuracy: 0.9444
# Epoch 98/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2061 - accuracy: 0.9444
# Epoch 99/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1296 - accuracy: 0.9444
# Epoch 100/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1993 - accuracy: 0.9444
# Epoch 101/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2095 - accuracy: 0.8889
# Epoch 102/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1971 - accuracy: 0.9444
# Epoch 103/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1012 - accuracy: 1.0000
# Epoch 104/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1397 - accuracy: 0.9444
# Epoch 105/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2172 - accuracy: 0.9444
# Epoch 106/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2249 - accuracy: 0.9444
# Epoch 107/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1451 - accuracy: 0.9444
# Epoch 108/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1727 - accuracy: 0.9444
# Epoch 109/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2037 - accuracy: 0.8889
# Epoch 110/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2381 - accuracy: 0.8889
# Epoch 111/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1255 - accuracy: 0.9444
# Epoch 112/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1376 - accuracy: 0.8889
# Epoch 113/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1485 - accuracy: 0.9444
# Epoch 114/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2553 - accuracy: 0.8889
# Epoch 115/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1763 - accuracy: 0.9444
# Epoch 116/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2130 - accuracy: 0.9444
# Epoch 117/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1511 - accuracy: 0.9444
# Epoch 118/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1227 - accuracy: 0.9444
# Epoch 119/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2301 - accuracy: 0.8333
# Epoch 120/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1941 - accuracy: 0.9444
# Epoch 121/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2705 - accuracy: 0.7778
# Epoch 122/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1684 - accuracy: 0.8889
# Epoch 123/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2486 - accuracy: 0.9444
# Epoch 124/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2735 - accuracy: 0.9444
# Epoch 125/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1637 - accuracy: 0.8889
# Epoch 126/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2287 - accuracy: 0.8889
# Epoch 127/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1552 - accuracy: 0.9444
# Epoch 128/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2210 - accuracy: 0.8889
# Epoch 129/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1844 - accuracy: 0.8889
# Epoch 130/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2093 - accuracy: 0.9444
# Epoch 131/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1715 - accuracy: 0.9444
# Epoch 132/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2542 - accuracy: 0.9444
# Epoch 133/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2405 - accuracy: 0.8889
# Epoch 134/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1558 - accuracy: 0.9444
# Epoch 135/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1425 - accuracy: 0.9444
# Epoch 136/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1470 - accuracy: 0.9444
# Epoch 137/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2352 - accuracy: 0.8889
# Epoch 138/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2391 - accuracy: 0.9444
# Epoch 139/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1384 - accuracy: 0.9444
# Epoch 140/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2357 - accuracy: 0.8889
# Epoch 141/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1339 - accuracy: 0.9444
# Epoch 142/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1361 - accuracy: 0.9444
# Epoch 143/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1644 - accuracy: 0.9444
# Epoch 144/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2007 - accuracy: 0.9444
# Epoch 145/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1268 - accuracy: 0.9444
# Epoch 146/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1294 - accuracy: 0.9444
# Epoch 147/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2236 - accuracy: 0.9444
# Epoch 148/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1724 - accuracy: 0.8889
# Epoch 149/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1666 - accuracy: 0.9444
# Epoch 150/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2184 - accuracy: 0.9444
# Epoch 151/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2140 - accuracy: 0.9444
# Epoch 152/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1156 - accuracy: 0.9444
# Epoch 153/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0925 - accuracy: 0.9444
# Epoch 154/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1480 - accuracy: 0.9444
# Epoch 155/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2229 - accuracy: 0.9444
# Epoch 156/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1419 - accuracy: 0.9444
# Epoch 157/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1390 - accuracy: 0.9444
# Epoch 158/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1826 - accuracy: 0.9444
# Epoch 159/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1373 - accuracy: 0.9444
# Epoch 160/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2584 - accuracy: 0.9444
# Epoch 161/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1779 - accuracy: 0.9444
# Epoch 162/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1897 - accuracy: 0.9444
# Epoch 163/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1402 - accuracy: 0.9444
# Epoch 164/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1745 - accuracy: 0.9444
# Epoch 165/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1057 - accuracy: 0.9444
# Epoch 166/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1686 - accuracy: 0.9444
# Epoch 167/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1373 - accuracy: 0.9444
# Epoch 168/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2104 - accuracy: 0.9444
# Epoch 169/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1005 - accuracy: 0.9444
# Epoch 170/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2645 - accuracy: 0.9444
# Epoch 171/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1396 - accuracy: 0.9444
# Epoch 172/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2343 - accuracy: 0.9444
# Epoch 173/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2540 - accuracy: 0.8889
# Epoch 174/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1563 - accuracy: 0.9444
# Epoch 175/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1918 - accuracy: 0.9444
# Epoch 176/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1395 - accuracy: 0.9444
# Epoch 177/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1814 - accuracy: 0.9444
# Epoch 178/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1540 - accuracy: 0.9444
# Epoch 179/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1785 - accuracy: 0.9444
# Epoch 180/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1254 - accuracy: 0.9444
# Epoch 181/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2045 - accuracy: 0.9444
# Epoch 182/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2128 - accuracy: 0.9444
# Epoch 183/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1627 - accuracy: 0.9444
# Epoch 184/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1400 - accuracy: 0.9444
# Epoch 185/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2043 - accuracy: 0.9444
# Epoch 186/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1340 - accuracy: 0.9444
# Epoch 187/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1636 - accuracy: 0.9444
# Epoch 188/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1574 - accuracy: 0.9444
# Epoch 189/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1920 - accuracy: 0.9444
# Epoch 190/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1618 - accuracy: 0.9444
# Epoch 191/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1228 - accuracy: 0.9444
# Epoch 192/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1868 - accuracy: 0.9444
# Epoch 193/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1156 - accuracy: 1.0000
# Epoch 194/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2058 - accuracy: 0.9444
# Epoch 195/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1316 - accuracy: 0.9444
# Epoch 196/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2051 - accuracy: 0.9444
# Epoch 197/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2152 - accuracy: 0.9444
# Epoch 198/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1290 - accuracy: 0.9444
# Epoch 199/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1493 - accuracy: 0.9444
# Epoch 200/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1470 - accuracy: 0.9444
# Done
# C:\Users\maheep seharawat\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
def send():
    send = "You -> " + e.get()
    txt.insert(END, "\n" + send)

    message = e.get().lower()

    message = input("")
    ints = predict_class (message)
    res = get_response (ints, intents)

    txt.insert(END,"\n"+res)
    e.delete(0, END)

# %%
intents = json.loads(open('intents1.json').read())
words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model('chatbot_model.h5')


def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
    return sentence_words

def bag_of_words (sentence):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for w in sentence_words:
        for i, word in enumerate(words):
            if word == w:
                bag[i] = 1
    return np.array(bag)

def predict_class (sentence):
    bow = bag_of_words (sentence)
    res = model.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]

    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({'intent': classes [r[0]], 'probability': str(r[1])})
    return return_list

def get_response(intents_list, intents_json):
    tag = intents_list[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice (i['responses'])
            break
    return result

print("GO! Bot is running!")
while True:
    message = input("")
    if(message=='break'):
        break
    ints = predict_class (message)
    res = get_response (ints, intents)
    print (res)
# Out:
# GO! Bot is running!
# hey
# 1/1 [==============================] - 0s 96ms/step
# Hello
# what is 2+3
# 1/1 [==============================] - 0s 45ms/step
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 48
#      46     break
#      47 ints = predict_class (message)
# ---> 48 res = get_response (ints, intents)
#      49 print (res)
#
# Cell In[6], line 40, in get_response(intents_list, intents_json)
#      38         result = random.choice (i['responses'])
#      39         break
# ---> 40 return result
#
# UnboundLocalError: cannot access local variable 'result' where it is not associated with a value
